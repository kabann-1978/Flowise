# %% [markdown]
# <a href="https://colab.research.google.com/github/kabann-1978/Flowise/blob/main/exemplo1_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib

# %%
from sklearn.datasets import make_regression
x, y = make_regression(n_samples=50, n_features=2, noise=10)
import matplotlib.pyplot as plt

# %%
plt.scatter(x,y)
plt.show()
